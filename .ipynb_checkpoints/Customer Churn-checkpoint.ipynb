# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings

# %%
dataset=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
dataset.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
dataset.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (7043, 21)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
dataset['TotalCharges']=dataset['TotalCharges'].replace(' ' ,np.nan)

# %%
dataset['TotalCharges']=dataset['TotalCharges'].astype('float')

# %%
dataset['TotalCharges'].fillna(dataset['TotalCharges'].mean() , inplace=True)
# Out:
# C:\Users\Zeeshan Murad\AppData\Local\Temp\ipykernel_9108\530822346.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['TotalCharges'].fillna(dataset['TotalCharges'].mean() , inplace=True)

# %%
dataset.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2265.000258
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1400.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
plt.title('Total Customers')
ax=sns.countplot(data=dataset ,x='Churn')
ax.bar_label(ax.containers[0])
plt.tight_layout()
plt.subplot(2,2,2)
gb=dataset.groupby('Churn').agg({'Churn':'count'})
plt.pie(gb['Churn'],labels=gb.index ,autopct='%1.2f%%')
plt.title('Total Customers')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
sns.countplot(data=dataset , x='gender' ,color='red' ,hue='Churn')
plt.tight_layout()
plt.subplot(2,1,2)
sns.countplot(data=dataset ,x='Contract' ,hue='Churn')
plt.tight_layout()
# Out:
# C:\Users\Zeeshan Murad\AppData\Local\Temp\ipykernel_9108\445594931.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.countplot(data=dataset , x='gender' ,color='red' ,hue='Churn')

# %%
plt.figure(figsize=(12,5))
plt.subplot(2,1,1)
sns.countplot(data=dataset ,x='PaymentMethod',hue='Churn')
plt.tight_layout()
plt.subplot(2,1,2)
sns.countplot(data=dataset ,x='PaperlessBilling',hue='Churn')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2,1,1)
sns.kdeplot(data=dataset, x='MonthlyCharges', hue='Churn', fill=True, common_norm=False)
plt.title('Distribution of Monthly Charges by Churn Status')
plt.xlabel('Monthly Charges')
plt.ylabel('Density')

plt.subplot(2,1,2)
sns.kdeplot(data=dataset, x='TotalCharges', hue='Churn', fill=True, common_norm=False)
plt.title('Distribution of Total Charges by Churn Status')
plt.xlabel('Total Charges')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='tenure', data=dataset)
plt.title('Customer Tenure by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Tenure (in months)')
plt.show()

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.5-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\zeeshan murad\appdata\local\programs\python\python314\lib\site-packages (from xgboost) (2.3.3)
# Requirement already satisfied: scipy in c:\users\zeeshan murad\appdata\local\programs\python\python314\lib\site-packages (from xgboost) (1.16.2)
# Downloading xgboost-3.0.5-py3-none-win_amd64.whl (56.8 MB)
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/56.8 MB ? eta -:--:--
#    ---------------------------------------- 0.5/56.8 MB 123.8 kB/s eta 0:07:35
#    ---------------------------------------- 0.5/56.8 MB 123.8 kB/s eta 0:07:35
#    ---------------------------------------- 0.5/56.8 MB 123.8 kB/s eta 0:07:35
#     --------------------------------------- 0.8/56.8 MB 189.6 kB/s eta 0:04:56
#     --------------------------------------- 0.8/56.8 MB 189.6 kB/s eta 0:04:56
#     --------------------------------------- 1.0/56.8 MB 246.8 kB/s eta 0:03:46
MB 1.3 MB/s eta 0:00:10
#    ------------------------------- -------- 44.8/56.8 MB 1.3 MB/s eta 0:00:10
#    ------------------------------- -------- 45.4/56.8 MB 1.3 MB/s eta 0:00:09
#    -------------------------------- ------- 45.6/56.8 MB 1.3 MB/s eta 0:00:09
#    -------------------------------- ------- 45.9/56.8 MB 1.3 MB/s eta 0:00:09
#    -------------------------------- ------- 46.1/56.8 MB 1.3 MB/s eta 0:00:09
#    -------------------------------- ------- 46.7/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 46.9/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 46.9/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 47.2/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 47.2/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 47.4/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 47.4/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 47.7/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 47.7/56.8 MB 1.3 MB/s eta 0:00:08
#    --------------------------------- ------ 48.0/56.8 MB 1.3 MB/s eta 0:00:07
#    --------------------------------- ------ 48.2/56.8 MB 1.3 MB/s eta 0:00:07
#    --------------------------------- ------ 48.2/56.8 MB 1.3 MB/s eta 0:00:07
#    ---------------------------------- ----- 48.5/56.8 MB 1.3 MB/s eta 0:00:07
#    ---------------------------------- ----- 48.8/56.8 MB 1.3 MB/s eta 0:00:07
#    ---------------------------------- ----- 49.0/56.8 MB 1.3 MB/s eta 0:00:07
#    ---------------------------------- ----- 49.3/56.8 MB 1.3 MB/s eta 0:00:06
#    ---------------------------------- ----- 49.5/56.8 MB 1.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 49.8/56.8 MB 1.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 50.1/56.8 MB 1.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 50.3/56.8 MB 1.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 50.3/56.8 MB 1.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 50.6/56.8 MB 1.3 MB/s eta 0:00:05
#    ----------------------------------- ---- 50.9/56.8 MB 1.3 MB/s eta 0:00:05
#    ------------------------------------ --- 51.4/56.8 MB 1.3 MB/s eta 0:00:05
#    ------------------------------------ --- 51.6/56.8 MB 1.3 MB/s eta 0:00:05
#    ------------------------------------ --- 51.9/56.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------ --- 52.2/56.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------ --- 52.4/56.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------- -- 53.0/56.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------- -- 53.2/56.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 53.7/56.8 MB 1.3 MB/s eta 0:00:03
#    -------------------------------------- - 54.0/56.8 MB 1.3 MB/s eta 0:00:03
#    -------------------------------------- - 54.5/56.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 55.1/56.8 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  55.6/56.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  55.8/56.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  56.4/56.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  56.6/56.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 56.8/56.8 MB 1.3 MB/s  0:00:48
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.5

# %% [markdown]
# ## Model Creation Buliding

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier ,AdaBoostClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder ,StandardScaler
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.metrics import classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 9
#       7 from sklearn.preprocessing import LabelEncoder ,StandardScaler
#       8 from sklearn.svm import SVC
# ----> 9 import xgboost as xgb
#      10 from sklearn.metrics import classification_report
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
dataset.drop('customerID' , axis=1 , inplace=True)

# %%
input_data=dataset.drop('Churn',axis=1)
output=dataset['Churn']

# %%
Le=LabelEncoder()
output_en=Le.fit(output)

# %%
input_data_en=pd.get_dummies(input_data)

# %%
input_data_en.isnull().sum()

# %%
X_train, X_test, y_train, y_test = train_test_split(input_data_en, output, test_size=0.2, random_state=42)

# %%
pipeline_Lr=Pipeline([
    ('St' , StandardScaler()),
    ('Lr',LogisticRegression(random_state=42,class_weight='balanced'))
]
)

# %%
pipeline_Dtr=Pipeline([
    ('St' , StandardScaler()),
    ('Dtr',DecisionTreeClassifier(random_state=42,class_weight='balanced'))
]
)

# %%
pipeline_Rdf=Pipeline([
    ('St' , StandardScaler()),
    ('Rdf',RandomForestClassifier(random_state=42,class_weight='balanced'))
]
)

# %%
pipeline_ada=Pipeline([
    ('St' , StandardScaler()),
    ('Ada',AdaBoostClassifier(random_state=42))
]
)

# %%
pipeline_knn=Pipeline([
    ('St' , StandardScaler()),
    ('knn',KNeighborsClassifier())
]
)

# %%
pipeline_svm=Pipeline([
    ('St' , StandardScaler()),
    ('svm',SVC(class_weight='balanced'))
]
)

# %%
pipeline_Lr.fit(X_train,y_train)

# %%
pipeline_Lr.score(X_test,y_test)*100

# %%
print('Classification Report' , classification_report(y_test ,pipeline_Lr.predict(X_test)))

# %%
pipeline_Dtr.fit(X_train,y_train)

# %%
print('Classification Report' , classification_report(y_test ,pipeline_Dtr.predict(X_test)))

# %%
pipeline_ada.fit(X_train,y_train)

# %%
print('Classification Report' , classification_report(y_test ,pipeline_ada.predict(X_test)))

# %%
pipeline_Rdf.fit(X_train,y_train)

# %%
print('Classification Report' , classification_report(y_test ,pipeline_Rdf.predict(X_test)))

# %%
pipeline_knn.fit(X_train,y_train)

# %%
print('Classification Report' , classification_report(y_test ,pipeline_Rdf.predict(X_test)))

# %%
pipeline_svm.fit(X_train,y_train)

# %%
print('Classification Report' , classification_report(y_test ,pipeline_svm.predict(X_test)))
